# %%
# Step 1: Load the CSV File
import pandas as pd

# Load the dataset from the CSV file
df = pd.read_csv('student_performance.csv')

# Display the first few rows of the dataframe
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0
# 2             0  0.112602         4.0
# 3             0  2.054218         3.0
# 4             0  1.288061         4.0

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Load the dataset
data = pd.read_csv('student_performance.csv')

# Display the first few rows of the dataset to understand its structure
data.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0
# 2             0  0.112602         4.0
# 3             0  2.054218         3.0
# 4             0  1.288061         4.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Feature selection and preprocessing
X = df.drop(['StudentID', 'GradeClass'], axis=1)  # Adjust as necessary
y = df['GradeClass']

# Handle missing values if any
X = X.fillna(X.mean())

# Standardize the features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the dataset from the CSV file
df = pd.read_csv('student_performance.csv')

# Feature selection and preprocessing
# Make sure the column names match those in your CSV file
X = df.drop(['StudentID', 'GradeClass'], axis=1)  # Adjust as necessary
y = df['GradeClass']

# Handle missing values if any
X = X.fillna(X.mean())

# Standardize the features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Print shapes to verify the splits
print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of y_test: {y_test.shape}")

# Print first few rows of X_train and X_test
print("First few rows of X_train:")
print(pd.DataFrame(X_train).head())

print("First few rows of X_test:")
print(pd.DataFrame(X_test).head())
# Out:
# Shape of X_train: (1674, 13)
# Shape of X_test: (718, 13)
# Shape of y_train: (1674,)
# Shape of y_test: (718,)
# First few rows of X_train:
#          0         1         2         3         4         5         6   \
# 0  1.362944  0.978492  1.091641 -0.746087 -1.061532 -0.890822 -0.656870
# 1 -1.307132 -1.021981  1.091641 -0.746087  0.296582  0.526671 -0.656870
# 2 -1.307132  0.978492  0.119125  0.253711  1.733693 -0.182076 -0.656870
# 3  1.362944  0.978492 -0.853391  0.253711  0.052978  0.644796 -0.656870
# 4  1.362944 -1.021981  0.119125 -0.746087 -1.347143  1.707916  1.522371
#
#          7         8         9         10        11        12
# 0 -0.108744  1.268269  1.514848 -0.495161  2.315535  0.676452
# 1 -0.108744 -0.788476 -0.660132 -0.495161 -0.431866 -1.119519
# 2 -0.999551 -0.788476 -0.660132 -0.495161 -0.431866  0.208160
# 3  1.672869 -0.788476 -0.660132 -0.495161 -0.431866 -0.639106
# 4  0.782063  1.268269  1.514848  2.019544  2.315535 -0.998825
# First few rows of X_test:
#          0         1         2         3         4         5        6   \
# 0 -1.307132  0.978492  1.091641  2.253308 -1.705047  0.290422 -0.65687
# 1 -0.417106  0.978492 -0.853391  2.253308 -1.376969 -1.717694 -0.65687
# 2 -1.307132 -1.021981 -0.853391 -1.745885  0.144512  0.054173 -0.65687
# 3  1.362944  0.978492  0.119125  0.253711  1.138912 -1.599569 -0.65687
# 4  1.362944 -1.021981 -0.853391 -1.745885 -1.096181  1.471667 -0.65687
#
#          7         8         9         10        11        12
# 0 -0.108744 -0.788476  1.514848  2.019544  2.315535 -0.522929
# 1 -0.999551  1.268269 -0.660132 -0.495161  2.315535  1.323732
# 2  0.782063 -0.788476 -0.660132 -0.495161  2.315535  0.143811
# 3  0.782063  1.268269 -0.660132 -0.495161 -0.431866  1.794970
# 4 -0.999551 -0.788476  1.514848 -0.495161 -0.431866 -1.811228

# %%
from sklearn.ensemble import RandomForestClassifier

# Train a Random Forest Classifier
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Print a message indicating training is complete
print("Model training complete.")
# Out:
# Model training complete.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score

# Make predictions
y_pred = model.predict(X_test)
y_proba = model.predict_proba(X_test)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-Score: {f1}")

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# ROC Curve and AUC
fpr, tpr, _ = roc_curve(y_test, y_proba[:, 1], pos_label=model.classes_[1])
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

print(f"AUC: {roc_auc}")

# Cross-validation
cv_scores = cross_val_score(model, X, y, cv=5)
mean_cv_score = cv_scores.mean()
std_cv_score = cv_scores.std()

print(f"Cross-Validation Mean Accuracy: {mean_cv_score}")
print(f"Cross-Validation Standard Deviation: {std_cv_score}")
# Out:
# Accuracy: 0.9164345403899722
# Precision: 0.9153245497637745
# Recall: 0.9164345403899722
# F1-Score: 0.9132249284737958
# Confusion Matrix:
# [[ 17   4   4   3   5]
#  [  2  68   3   2   5]
#  [  0   3 108   5   5]
#  [  0   2   4 113   8]
#  [  0   2   0   3 352]]
# AUC: 0.9468847962382445
# Cross-Validation Mean Accuracy: 0.9192590910282055
# Cross-Validation Standard Deviation: 0.1190927854266572

# %% [markdown]
# # New Section
